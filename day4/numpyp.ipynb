# %% [markdown]
# <a href="https://colab.research.google.com/github/dixondanty/AI-ML-internship/blob/main/day4/numpyp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
arr = np.array([1,2,3])
print(arr)
# Out:
# [1 2 3]

# %%
type(arr)
# Out:
# numpy.ndarray

# %%
arr.shape
# Out:
# (3,)

# %%
arr1 = np.array([1, 2, 3])
arr2 = np.array([4, 5, 6])

# Addition
print("Addition:", arr1 + arr2)

# Multiplication
print("Multiplication:", arr1 * arr2)
# Out:
# Addition: [5 7 9]
# Multiplication: [ 4 10 18]

# %%
arr = np.arange(1, 10)

new_arr = arr.reshape(3, 3)

print(new_arr)
# Out:
# [[1 2 3]
#  [4 5 6]
#  [7 8 9]]

# %%
# Create a two-dimensional array
arr2 = np.array([[1,2],[3,4]])
print(arr2)
# Out:
# [[1 2]
#  [3 4]]

# %%
arr2.shape
# Out:
# (2, 2)

# %%
# Create a three-dimensional array
threeD_array = np.array([[[1,2],[3,4]],
                        [[5,6],[7,8]]])
print(threeD_array)
print(threeD_array.shape)
# Out:
# [[[1 2]
#   [3 4]]
#
#  [[5 6]
#   [7 8]]]
# (2, 2, 2)

# %%
py_list = [1, 2, 3]
print(py_list*2)
# Out:
# [1, 2, 3, 1, 2, 3]

# %%
# NumPy array
np_array = np.array([1, 2, 3])
print(np_array*2)
# Out:
# [2 4 6]
