# %% [markdown]
# <a href="https://colab.research.google.com/github/dixondanty/AI-ML-internship/blob/main/day4/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = {"Name": ["Asha", "Rahul", "Neha"],"Marks": [85, 90, 78]}
df = pd.DataFrame(data)
print(df)
# Out:
#     Name  Marks
# 0   Asha     85
# 1  Rahul     90
# 2   Neha     78

# %%
import numpy as np
data_dict = {'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva', 'Eva'], 'Age': [25, np.nan, 30, 22, 28, 28],
'Score': [85, 90, 95, 80, 70, 70]}
df = pd.DataFrame(data_dict)
print(df)
# Out:
#       Name   Age  Score
# 0    Alice  25.0     85
# 1      Bob   NaN     90
# 2  Charlie  30.0     95
# 3    David  22.0     80
# 4      Eva  28.0     70
# 5      Eva  28.0     70

# %%
print("Null values per column:\n", df.isnull().sum())
# Out:
# Null values per column:
#  Name     0
# Age      1
# Score    0
# dtype: int64
